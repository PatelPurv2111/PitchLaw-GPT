# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader("../data/fifa_laws_of_game.pdf")
documents=loader.load()
print("Total Documents:",len(documents))
documents[0]
# Out:
# Total Documents: 116
# Document(metadata={'producer': 'macOS Version 15.7.4 (Build 24G517) Quartz PDFContext, AppendMode 1.1', 'creator': 'Adobe InDesign 20.3 (Windows)', 'creationdate': '2025-05-16T11:02:31+02:00', 'trapped': '/False', 'moddate': "D:20260313065256Z00'00'", 'source': '../data/fifa_laws_of_game.pdf', 'total_pages': 116, 'page': 0, 'page_label': '1'}, page_content='1\nLaws \nof the Game\n25/26\nLaws of the Game   2025/26')
