# %%
import pandas as pd
from pypdf import PdfReader
reader=PdfReader("../data/fifa_laws_of_game.pdf")
print("Total Pages:",len(reader.pages))
text=reader.pages[0].extract_text()
print(text[:500])
# Out:
# Total Pages: 116
# 1
# Laws
# of the Game
# 25/26
# Laws of the Game   2025/26
